# %% [markdown]
# ## Module responsible for Forecasting using ARIMA

# %%
import numpy as np 
from matplotlib.pyplot import plot,show
import pmdarima as pm
from sklearn.metrics import mean_squared_error as mse

# %%
exp1 = np.loadtxt(r'./NORMAL/File0/orientation.csv')
exp2= np.loadtxt(r'./NORMAL/File1/orientation.csv')
exp3= np.loadtxt(r'./NORMAL/File2/orientation.csv')
exp4= np.loadtxt(r'./NORMAL/File3/orientation.csv')
exp5= np.loadtxt(r'./NORMAL/File4/orientation.csv')
g = np.concatenate((exp1,exp2,exp3,exp4,exp5), axis=1)

# %%
x= g[0,:] # each row of g is a time series (x,y,z,w)

xtrain = x[:(int(0.8 * np.size(x, 0)))]
xtest = x[(int(0.8 * np.size(x, 0))):]

# %%
information_criterion = ["aic", "bic", "hqic", "oob"]
method = ["newton", "nm", "bfgs", "lbfgs", "powell", "cg", "ncg", "basinhopping"]
test = ["kpss", "pp", "adf"]
Error=[]
meth=[]
tes=[]
ic=[]

# %%
for i in information_criterion:
    for t in test:
            model = pm.auto_arima(xtrain, n_jobs=1, trace=True, error_action='ignore', suppress_warnings=False, information_criterion= i, test=t,maxiter=100)
            prediction=[]

            hist = [x for x in xtrain]
            for x in xtest[:10]:
                        model.fit(hist)
                        prediction.append(model.predict(1))
                        hist.append(x)
            e = mse(xtest[:10], prediction)
            Error.append(e)
            ic.append(i)
        
            #meth.append(m)
        
            tes.append(t)
            print(" configuration with information_criterion=", i, "method =", "maxiter=100","test=", t, "with error=", e)
# Out:
# Performing stepwise search to minimize aic
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3403.998, BIC=-3378.105, Time=0.688 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3318.093, BIC=-3309.463, Time=0.049 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3449.173, BIC=-3436.226, Time=0.095 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3425.814, BIC=-3412.868, Time=0.151 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-3320.088, BIC=-3315.773, Time=0.062 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3447.278, BIC=-3430.016, Time=0.086 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3447.254, BIC=-3429.993, Time=0.179 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3445.169, BIC=-3423.592, Time=0.298 seconds
# Total fit time: 1.612 seconds
#  configuration with information_criterion= aic method = maxiter=100 test= kpss with error= 7.8303821304175e-05
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.261 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.056 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.061 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.288 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.027 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.223 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.236 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.238 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3482.571, BIC=-3465.302, Time=0.157 seconds
# Fit ARIMA: (3, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3481.770, BIC=-3460.184, Time=0.135 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.287 seconds
# Total fit time: 1.974 seconds
#  configuration with information_criterion= aic method = maxiter=100 test= pp with error= 8.082256190300108e-05
# Performing stepwise search to minimize aic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.280 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.059 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.064 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.256 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.026 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.231 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.230 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.248 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3482.571, BIC=-3465.302, Time=0.156 seconds
# Fit ARIMA: (3, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3481.770, BIC=-3460.184, Time=0.132 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.282 seconds
# Total fit time: 1.969 seconds
#  configuration with information_criterion= aic method = maxiter=100 test= adf with error= 8.082256190300108e-05
# Performing stepwise search to minimize bic
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3403.998, BIC=-3378.105, Time=0.762 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3318.093, BIC=-3309.463, Time=0.054 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3449.173, BIC=-3436.226, Time=0.102 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3425.814, BIC=-3412.868, Time=0.161 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-3320.088, BIC=-3315.773, Time=0.067 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3447.278, BIC=-3430.016, Time=0.096 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3447.254, BIC=-3429.993, Time=0.193 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3445.169, BIC=-3423.592, Time=0.326 seconds
# Total fit time: 1.766 seconds
#  configuration with information_criterion= bic method = maxiter=100 test= kpss with error= 7.8303821304175e-05
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.274 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.097 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.062 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.239 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.025 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.199 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.215 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.250 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3482.571, BIC=-3465.302, Time=0.147 seconds
# Fit ARIMA: (3, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3481.770, BIC=-3460.184, Time=0.121 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.263 seconds
# Total fit time: 1.897 seconds
#  configuration with information_criterion= bic method = maxiter=100 test= pp with error= 8.082256190300108e-05
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.281 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.060 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.065 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.265 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.027 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.217 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.229 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.258 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3482.571, BIC=-3465.302, Time=0.174 seconds
# Fit ARIMA: (3, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3481.770, BIC=-3460.184, Time=0.136 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.273 seconds
# Total fit time: 1.992 seconds
#  configuration with information_criterion= bic method = maxiter=100 test= adf with error= 8.082256190300108e-05
# Performing stepwise search to minimize hqic
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3403.998, BIC=-3378.105, Time=0.729 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3318.093, BIC=-3309.463, Time=0.068 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3449.173, BIC=-3436.226, Time=0.092 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3425.814, BIC=-3412.868, Time=0.144 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-3320.088, BIC=-3315.773, Time=0.063 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3447.278, BIC=-3430.016, Time=0.086 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3447.254, BIC=-3429.993, Time=0.176 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3445.169, BIC=-3423.592, Time=0.318 seconds
# Total fit time: 1.679 seconds
#  configuration with information_criterion= hqic method = maxiter=100 test= kpss with error= 7.8303821304175e-05
# Performing stepwise search to minimize hqic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.255 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.053 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.058 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.240 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.025 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.190 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.204 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.227 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3482.571, BIC=-3465.302, Time=0.150 seconds
# Fit ARIMA: (3, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3481.770, BIC=-3460.184, Time=0.130 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.257 seconds
# Total fit time: 1.795 seconds
#  configuration with information_criterion= hqic method = maxiter=100 test= pp with error= 8.082256190300108e-05
# Performing stepwise search to minimize hqic
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.280 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.063 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.061 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.242 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.024 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.194 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.208 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.234 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3482.571, BIC=-3465.302, Time=0.143 seconds
# Fit ARIMA: (3, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3481.770, BIC=-3460.184, Time=0.117 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.255 seconds
# Total fit time: 1.824 seconds
#  configuration with information_criterion= hqic method = maxiter=100 test= adf with error= 8.082256190300108e-05
# Performing stepwise search to minimize oob
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3403.998, BIC=-3378.105, Time=0.688 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3318.093, BIC=-3309.463, Time=0.049 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3449.173, BIC=-3436.226, Time=0.093 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3425.814, BIC=-3412.868, Time=0.148 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-3320.088, BIC=-3315.773, Time=0.062 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3445.773, BIC=-3424.196, Time=0.113 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3445.169, BIC=-3423.592, Time=0.301 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3442.752, BIC=-3412.545, Time=0.727 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-3445.322, BIC=-3415.115, Time=0.171 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3447.254, BIC=-3429.993, Time=0.178 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-3443.434, BIC=-3417.542, Time=0.275 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.936, BIC=-3419.044, Time=0.267 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (3, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-3442.941, BIC=-3408.418, Time=0.614 seconds
# Total fit time: 3.691 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  configuration with information_criterion= oob method = maxiter=100 test= kpss with error= 9.169581703003076e-05
# Performing stepwise search to minimize oob
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.253 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.071 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.067 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.260 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.025 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.258 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.228 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3477.809, BIC=-3447.589, Time=0.264 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-3477.582, BIC=-3447.362, Time=0.609 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.226 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-3475.077, BIC=-3449.174, Time=0.834 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.250 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-3476.218, BIC=-3441.680, Time=0.925 seconds
# Total fit time: 4.275 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#  configuration with information_criterion= oob method = maxiter=100 test= pp with error= 7.802806575933372e-05
# Performing stepwise search to minimize oob
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3479.576, BIC=-3453.673, Time=0.257 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-1942.475, BIC=-1933.840, Time=0.056 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=-3330.342, BIC=-3317.390, Time=0.060 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-2568.150, BIC=-2555.199, Time=0.236 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=-1254.800, BIC=-1250.483, Time=0.024 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3471.193, BIC=-3449.608, Time=0.198 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3481.363, BIC=-3459.778, Time=0.214 seconds
# Fit ARIMA: (3, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=-3477.809, BIC=-3447.589, Time=0.261 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-3477.582, BIC=-3447.362, Time=0.603 seconds
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.215, BIC=-3426.946, Time=0.227 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-3475.077, BIC=-3449.174, Time=0.840 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=-3478.115, BIC=-3452.212, Time=0.251 seconds
# Fit ARIMA: (3, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=-3476.218, BIC=-3441.680, Time=0.929 seconds
# Total fit time: 4.160 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#  configuration with information_criterion= oob method = maxiter=100 test= adf with error= 7.802806575933372e-05

# %%
minErridx= Error.index(min(Error))
print("Best config : Information Criterion==",ic[minErridx],  "test==",tes[minErridx], "   with MSE Error==", Error[minErridx])
bestmodel= pm.auto_arima(xtrain, n_jobs=1, trace=True, error_action='ignore', suppress_warnings=False, information_criterion= ic[minErridx], test=tes[minErridx],maxiter=100)
prediction=[]

hist = [x for x in xtrain]
for x in xtest:
        bestmodel.fit(hist)
        prediction.append(bestmodel.predict(1))
        hist.append(x)
print("MSE is", mse(xtest, prediction))
plot(xtest,color='r')
plot(prediction,color='b')
show()
# Out:
# Best config : Information Criterion== oob test== kpss    with MSE Error== 1.99623529363702e-05
# Performing stepwise search to minimize oob
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3403.998, BIC=-3378.105, Time=0.724 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3318.093, BIC=-3309.463, Time=0.072 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=-3449.173, BIC=-3436.226, Time=0.098 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3425.814, BIC=-3412.868, Time=0.170 seconds
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=False); AIC=-3320.088, BIC=-3315.773, Time=0.064 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3445.773, BIC=-3424.196, Time=0.118 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3445.169, BIC=-3423.592, Time=0.332 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=-3442.752, BIC=-3412.545, Time=0.767 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-3445.322, BIC=-3415.115, Time=0.169 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3447.254, BIC=-3429.993, Time=0.179 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-3443.434, BIC=-3417.542, Time=0.281 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=-3444.936, BIC=-3419.044, Time=0.293 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: (3, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=-3442.941, BIC=-3408.418, Time=0.640 seconds
# Total fit time: 3.913 seconds
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/dzilla69/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# MSE is 9.925223232169232e-05
